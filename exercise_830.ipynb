# %% [markdown]
# # Image Classification using a Single Layer Neural Network
#
# We first measure the performance of a single layer neural network on the MNIST dataset to set a baseline.
#
# Though there is just one layer involved, we've wrapped it in an **nn.Sequential** object to make the model easier to extend.

# %%
# Code adapted from https://github.com/activatedgeek/LeNet-5/

from collections import OrderedDict
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision.datasets.mnist import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

class SoftmaxRegression(nn.Module):
    """
    Input - 1x32x32
    Output - 10 (Output)
    """
    def __init__(self):
        super(SoftmaxRegression, self).__init__()

        self.fc = nn.Sequential(OrderedDict([
            ('linear_combination', nn.Linear(32 * 32, 10)),
        ]))

    def forward(self, img):
        output = img.view(-1, 32 * 32)
        output = self.fc(output)
        return output
    

data_train = MNIST('data/mnist',
                   download=True,
                   transform=transforms.Compose([
                       transforms.Resize((32, 32)),
                       transforms.ToTensor()]))
data_test = MNIST('data/mnist',
                  train=False,
                  download=True,
                  transform=transforms.Compose([
                      transforms.Resize((32, 32)),
                      transforms.ToTensor()]))
data_train_loader = DataLoader(data_train, batch_size=256, shuffle=True, num_workers=8)
data_test_loader = DataLoader(data_test, batch_size=1024, num_workers=8)

net = SoftmaxRegression()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=2e-3)

def train(epoch):
    net.train()
    loss_list, batch_list = [], []
    for i,(images, labels) in enumerate(data_train_loader):
        images, labels = Variable(images), Variable(labels)

        optimizer.zero_grad()

        output = net(images)

        loss = criterion(output, labels)

        loss_list.append(loss.data[0])
        batch_list.append(i+1)

        if i % 10 == 0:
            print('Train - Epoch %d, Batch: %d, Loss: %f' % (epoch, i, loss.data[0]))

        loss.backward()
        optimizer.step()


def test():
    net.eval()
    total_correct = 0
    avg_loss = 0.0
    for i, (images, labels) in enumerate(data_test_loader):
        images, labels = Variable(images), Variable(labels)
        output = net(images)
        avg_loss += criterion(output, labels).sum()
        pred = output.data.max(1)[1]
        total_correct += pred.eq(labels.data.view_as(pred)).sum()

    avg_loss /= len(data_test)
    print('Test Avg. Loss: %f, Accuracy: %f' % (avg_loss.data[0], float(total_correct) / len(data_test)))


def train_and_test(epoch):
    train(epoch)
    test()


def main():
    for e in range(1, 5):  # Change 5 to 16 for better performance
        train_and_test(e)


if __name__ == '__main__':
    main()
# Out:
# Train - Epoch 1, Batch: 0, Loss: 2.294825
# Train - Epoch 1, Batch: 10, Loss: 1.418247
# Train - Epoch 1, Batch: 20, Loss: 0.987573
# Train - Epoch 1, Batch: 30, Loss: 0.762353
# Train - Epoch 1, Batch: 40, Loss: 0.720855
# Train - Epoch 1, Batch: 50, Loss: 0.623581
# Train - Epoch 1, Batch: 60, Loss: 0.521776
# Train - Epoch 3, Batch: 50, Loss: 0.301749
# Train - Epoch 3, Batch: 60, Loss: 0.315046
# Train - Epoch 3, Batch: 70, Loss: 0.258487
# Train - Epoch 3, Batch: 80, Loss: 0.317021
# Train - Epoch 3, Batch: 90, Loss: 0.337453
# Train - Epoch 3, Batch: 100, Loss: 0.223472
# Train - Epoch 3, Batch: 110, Loss: 0.325194
# Train - Epoch 3, Batch: 120, Loss: 0.349766
# Train - Epoch 3, Batch: 130, Loss: 0.284584
# Train - Epoch 3, Batch: 140, Loss: 0.341743
# Train - Epoch 3, Batch: 150, Loss: 0.280891
# Train - Epoch 3, Batch: 160, Loss: 0.288747
# Train - Epoch 3, Batch: 170, Loss: 0.337521
# Train - Epoch 3, Batch: 180, Loss: 0.322602
# Train - Epoch 3, Batch: 190, Loss: 0.291878
# Train - Epoch 3, Batch: 200, Loss: 0.296064
# Train - Epoch 3, Batch: 210, Loss: 0.353447
# Train - Epoch 3, Batch: 220, Loss: 0.318583
# Train - Epoch 3, Batch: 230, Loss: 0.276878
# Test Avg. Loss: 0.000284, Accuracy: 0.920400
# Train - Epoch 4, Batch: 0, Loss: 0.279354
# Train - Epoch 4, Batch: 10, Loss: 0.300652
# Train - Epoch 4, Batch: 20, Loss: 0.296830
# Train - Epoch 4, Batch: 30, Loss: 0.294727
# Train - Epoch 4, Batch: 40, Loss: 0.323929
# Train - Epoch 4, Batch: 50, Loss: 0.289714
# Train - Epoch 4, Batch: 60, Loss: 0.266330
# Train - Epoch 4, Batch: 70, Loss: 0.290107
# Train - Epoch 4, Batch: 80, Loss: 0.270218
# Train - Epoch 4, Batch: 90, Loss: 0.292076
# Train - Epoch 4, Batch: 100, Loss: 0.316935
# Train - Epoch 4, Batch: 110, Loss: 0.344641
# Train - Epoch 4, Batch: 120, Loss: 0.195196
# Train - Epoch 4, Batch: 130, Loss: 0.299579
# Train - Epoch 4, Batch: 140, Loss: 0.248681
# Train - Epoch 4, Batch: 150, Loss: 0.259875
# Train - Epoch 4, Batch: 160, Loss: 0.217706
# Train - Epoch 4, Batch: 170, Loss: 0.266048
# Train - Epoch 4, Batch: 180, Loss: 0.217655
# Train - Epoch 4, Batch: 190, Loss: 0.248036
# Train - Epoch 4, Batch: 200, Loss: 0.244599
# Train - Epoch 4, Batch: 210, Loss: 0.319495
# Train - Epoch 4, Batch: 220, Loss: 0.324758
# Train - Epoch 4, Batch: 230, Loss: 0.361883
# Test Avg. Loss: 0.000276, Accuracy: 0.922600

# %% [markdown]
# The accuracy we measure is around 92%, which is not bad, but not anywhere close to the best performing models on the MNIST dataset.
