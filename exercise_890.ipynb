# %% [markdown]
# # Image Classification using a Convolutional Neural Network
#
# Next, we measure the performance of the LeNet 5 convolutional neural network (simplified and using ReLUs) on the MNIST dataset.

# %%
# Code adapted from https://github.com/activatedgeek/LeNet-5/

from collections import OrderedDict
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision.datasets.mnist import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

class LeNet5(nn.Module):
    """
    Input - 1x32x32
    C1 - 6@28x28 (5x5 kernel)
    S2 - 6@14x14 (2x2 kernel, stride 2) Subsampling
    C3 - 16@10x10 (5x5 kernel, complicated shit simplified here)
    S4 - 16@5x5 (2x2 kernel, stride 2) Subsampling
    C5 - 120@1x1 (5x5 kernel)
    F6 - 84
    F7 - 10 (Output)
    """
    def __init__(self):
        super(LeNet5, self).__init__()

        self.convnet = nn.Sequential(OrderedDict([
            ('c1', nn.Conv2d(1, 6, kernel_size=(5, 5))),
            ('relu1', nn.ReLU()),
            ('s2', nn.MaxPool2d(kernel_size=(2, 2), stride=2)),
            ('c3', nn.Conv2d(6, 16, kernel_size=(5, 5))),
            ('relu3', nn.ReLU()),
            ('s4', nn.MaxPool2d(kernel_size=(2, 2), stride=2)),
            ('c5', nn.Conv2d(16, 120, kernel_size=(5, 5))),
            ('relu5', nn.ReLU())
        ]))

        self.fc = nn.Sequential(OrderedDict([
            ('f6', nn.Linear(120, 84)),
            ('relu6', nn.ReLU()),
            ('f7', nn.Linear(84, 10)),
            #('sig7', nn.LogSoftmax())
        ]))

    def forward(self, img):
        output = self.convnet(img)
        output = output.view(-1, 120)
        output = self.fc(output)
        return output
    

data_train = MNIST('data/mnist',
                   download=True,
                   transform=transforms.Compose([
                       transforms.Resize((32, 32)),
                       transforms.ToTensor()]))
data_test = MNIST('data/mnist',
                  train=False,
                  download=True,
                  transform=transforms.Compose([
                      transforms.Resize((32, 32)),
                      transforms.ToTensor()]))
data_train_loader = DataLoader(data_train, batch_size=256, shuffle=True, num_workers=8)
data_test_loader = DataLoader(data_test, batch_size=1024, num_workers=8)

net = LeNet5()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=2e-3)

def train(epoch):
    net.train()
    loss_list, batch_list = [], []
    for i,(images, labels) in enumerate(data_train_loader):
        images, labels = Variable(images), Variable(labels)

        optimizer.zero_grad()

        output = net(images)

        loss = criterion(output, labels)

        loss_list.append(loss.data.item())
        batch_list.append(i+1)

        if i % 10 == 0:
            print('Train - Epoch %d, Batch: %d, Loss: %f' % (epoch, i, loss.data.item()))

        loss.backward()
        optimizer.step()


def test():
    net.eval()
    total_correct = 0
    avg_loss = 0.0
    for i, (images, labels) in enumerate(data_test_loader):
        images, labels = Variable(images), Variable(labels)
        output = net(images)
        avg_loss += criterion(output, labels).sum()
        pred = output.data.max(1)[1]
        total_correct += pred.eq(labels.data.view_as(pred)).sum()

    avg_loss /= len(data_test)
    print('Test Avg. Loss: %f, Accuracy: %f' % (avg_loss.data.item(), float(total_correct) / len(data_test)))


# Test Avg. Loss: 0.000067, Accuracy: 0.979700
# Train - Epoch 3, Batch: 0, Loss: 0.110534
# Train - Epoch 3, Batch: 10, Loss: 0.066600
# Train - Epoch 3, Batch: 20, Loss: 0.047421
# Train - Epoch 3, Batch: 30, Loss: 0.055482
# Train - Epoch 3, Batch: 40, Loss: 0.111191
# Train - Epoch 3, Batch: 50, Loss: 0.038835
# Train - Epoch 3, Batch: 60, Loss: 0.050377
# Train - Epoch 3, Batch: 70, Loss: 0.085011
# Train - Epoch 3, Batch: 80, Loss: 0.088780
# Train - Epoch 3, Batch: 90, Loss: 0.106444
# Train - Epoch 3, Batch: 100, Loss: 0.045506
# Train - Epoch 3, Batch: 110, Loss: 0.058043
# Train - Epoch 3, Batch: 120, Loss: 0.112343
# Train - Epoch 3, Batch: 130, Loss: 0.051013
# Train - Epoch 3, Batch: 140, Loss: 0.035678
# Train - Epoch 3, Batch: 150, Loss: 0.035921
# Train - Epoch 3, Batch: 160, Loss: 0.054806
# Train - Epoch 3, Batch: 170, Loss: 0.053535
# Train - Epoch 3, Batch: 180, Loss: 0.046038
# Train - Epoch 3, Batch: 190, Loss: 0.075234
# Train - Epoch 3, Batch: 200, Loss: 0.086756
# Train - Epoch 3, Batch: 210, Loss: 0.034452
# Train - Epoch 3, Batch: 220, Loss: 0.102201
# Train - Epoch 3, Batch: 230, Loss: 0.034933
# Test Avg. Loss: 0.000049, Accuracy: 0.984800
# Train - Epoch 4, Batch: 0, Loss: 0.046859
# Train - Epoch 4, Batch: 10, Loss: 0.038555
# Train - Epoch 4, Batch: 20, Loss: 0.047358
# Train - Epoch 4, Batch: 30, Loss: 0.031504
# Train - Epoch 4, Batch: 40, Loss: 0.072512
# Train - Epoch 4, Batch: 50, Loss: 0.087102
# Train - Epoch 4, Batch: 60, Loss: 0.045428
# Train - Epoch 4, Batch: 70, Loss: 0.071275
# Train - Epoch 4, Batch: 80, Loss: 0.011162
# Train - Epoch 4, Batch: 90, Loss: 0.077916
# Train - Epoch 4, Batch: 100, Loss: 0.027565
# Train - Epoch 4, Batch: 110, Loss: 0.086171
# Train - Epoch 4, Batch: 120, Loss: 0.028585
# Train - Epoch 4, Batch: 130, Loss: 0.090734
# Train - Epoch 4, Batch: 140, Loss: 0.020315
# Train - Epoch 4, Batch: 150, Loss: 0.069799
# Train - Epoch 4, Batch: 160, Loss: 0.047289
# Train - Epoch 4, Batch: 170, Loss: 0.067304
# Train - Epoch 4, Batch: 180, Loss: 0.085657
# Train - Epoch 4, Batch: 190, Loss: 0.079578
# Train - Epoch 4, Batch: 200, Loss: 0.046732
# Train - Epoch 4, Batch: 210, Loss: 0.047001
# Train - Epoch 4, Batch: 220, Loss: 0.009123
# Train - Epoch 4, Batch: 230, Loss: 0.024981
# Test Avg. Loss: 0.000044, Accuracy: 0.986100

# %% [markdown]
# The accuracy we get with LeNet is above 98%.
