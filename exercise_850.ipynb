# %% [markdown]
# # Image Classification using a Multi-Layer Neural Network
#
# Next, we measure the performance of a multi-layer neural network on the MNIST dataset to set a baseline.
#
# The layers of the same are wrapped in an **nn.Sequential** object.

# %%
# Code adapted from https://github.com/activatedgeek/LeNet-5/

from collections import OrderedDict
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision.datasets.mnist import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

class MultilayerClassifier(nn.Module):
    """
    Input - 1x32x32
    Output - 10 (Output)
    """
    def __init__(self):
        super(MultilayerClassifier, self).__init__()

        self.fc = nn.Sequential(OrderedDict([
            ('linear_combination', nn.Linear(32 * 32, 32 * 4)),
            ('relu1', nn.ReLU()),
            ('fc2', nn.Linear(32 * 4, 10)),
        ]))

    def forward(self, img):
        output = img.view(-1, 32 * 32)
        output = self.fc(output)
        return output
    

data_train = MNIST('data/mnist',
                   download=True,
                   transform=transforms.Compose([
                       transforms.Resize((32, 32)),
                       transforms.ToTensor()]))
data_test = MNIST('data/mnist',
                  train=False,
                  download=True,
                  transform=transforms.Compose([
                      transforms.Resize((32, 32)),
                      transforms.ToTensor()]))
data_train_loader = DataLoader(data_train, batch_size=256, shuffle=True, num_workers=8)
data_test_loader = DataLoader(data_test, batch_size=1024, num_workers=8)

net = MultilayerClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=2e-3)

def train(epoch):
    net.train()
    loss_list, batch_list = [], []
    for i,(images, labels) in enumerate(data_train_loader):
        images, labels = Variable(images), Variable(labels)

        optimizer.zero_grad()

        output = net(images)

        loss = criterion(output, labels)

        loss_list.append(loss.data[0])
        batch_list.append(i+1)

        if i % 10 == 0:
            print('Train - Epoch %d, Batch: %d, Loss: %f' % (epoch, i, loss.data[0]))

        loss.backward()
        optimizer.step()


def test():
    net.eval()
    total_correct = 0
    avg_loss = 0.0
    for i, (images, labels) in enumerate(data_test_loader):
        images, labels = Variable(images), Variable(labels)
        output = net(images)
        avg_loss += criterion(output, labels).sum()
        pred = output.data.max(1)[1]
        total_correct += pred.eq(labels.data.view_as(pred)).sum()

    avg_loss /= len(data_test)
    print('Test Avg. Loss: %f, Accuracy: %f' % (avg_loss.data[0], float(total_correct) / len(data_test)))


def train_and_test(epoch):
    train(epoch)
    test()


def main():
    for e in range(1, 5):  # Change 5 to 16 for better performance
        train_and_test(e)


if __name__ == '__main__':
    main()
# Out:
# Train - Epoch 1, Batch: 0, Loss: 2.301226
# Train - Epoch 1, Batch: 10, Loss: 1.186535
# Train - Epoch 1, Batch: 20, Loss: 0.604144
# Train - Epoch 1, Batch: 30, Loss: 0.517013
# Train - Epoch 1, Batch: 40, Loss: 0.448800
# Train - Epoch 1, Batch: 50, Loss: 0.341987
# Train - Epoch 3, Batch: 40, Loss: 0.131920
# Train - Epoch 3, Batch: 50, Loss: 0.203787
# Train - Epoch 3, Batch: 60, Loss: 0.069233
# Train - Epoch 3, Batch: 70, Loss: 0.145226
# Train - Epoch 3, Batch: 80, Loss: 0.145736
# Train - Epoch 3, Batch: 90, Loss: 0.113723
# Train - Epoch 3, Batch: 100, Loss: 0.099565
# Train - Epoch 3, Batch: 110, Loss: 0.138359
# Train - Epoch 3, Batch: 120, Loss: 0.109923
# Train - Epoch 3, Batch: 130, Loss: 0.170786
# Train - Epoch 3, Batch: 140, Loss: 0.133581
# Train - Epoch 3, Batch: 150, Loss: 0.228459
# Train - Epoch 3, Batch: 160, Loss: 0.069677
# Train - Epoch 3, Batch: 170, Loss: 0.087336
# Train - Epoch 3, Batch: 180, Loss: 0.185760
# Train - Epoch 3, Batch: 190, Loss: 0.117573
# Train - Epoch 3, Batch: 200, Loss: 0.113332
# Train - Epoch 3, Batch: 210, Loss: 0.147557
# Train - Epoch 3, Batch: 220, Loss: 0.172392
# Train - Epoch 3, Batch: 230, Loss: 0.133183
# Test Avg. Loss: 0.000111, Accuracy: 0.967300
# Train - Epoch 4, Batch: 0, Loss: 0.090459
# Train - Epoch 4, Batch: 10, Loss: 0.138652
# Train - Epoch 4, Batch: 20, Loss: 0.097513
# Train - Epoch 4, Batch: 30, Loss: 0.074468
# Train - Epoch 4, Batch: 40, Loss: 0.117769
# Train - Epoch 4, Batch: 50, Loss: 0.058874
# Train - Epoch 4, Batch: 60, Loss: 0.116586
# Train - Epoch 4, Batch: 70, Loss: 0.065312
# Train - Epoch 4, Batch: 80, Loss: 0.095687
# Train - Epoch 4, Batch: 90, Loss: 0.139072
# Train - Epoch 4, Batch: 100, Loss: 0.046726
# Train - Epoch 4, Batch: 110, Loss: 0.082808
# Train - Epoch 4, Batch: 120, Loss: 0.078850
# Train - Epoch 4, Batch: 130, Loss: 0.058141
# Train - Epoch 4, Batch: 140, Loss: 0.050299
# Train - Epoch 4, Batch: 150, Loss: 0.079943
# Train - Epoch 4, Batch: 160, Loss: 0.127530
# Train - Epoch 4, Batch: 170, Loss: 0.092410
# Train - Epoch 4, Batch: 180, Loss: 0.037550
# Train - Epoch 4, Batch: 190, Loss: 0.094087
# Train - Epoch 4, Batch: 200, Loss: 0.150422
# Train - Epoch 4, Batch: 210, Loss: 0.128368
# Train - Epoch 4, Batch: 220, Loss: 0.077123
# Train - Epoch 4, Batch: 230, Loss: 0.067421
# Test Avg. Loss: 0.000098, Accuracy: 0.969800

# %% [markdown]
# The accuracy we get with just two layers is around 97%, which is a huge improvement over single-layer models on the MNIST dataset.
