# %% [markdown]
# # Image Classification using a 7-Layer Neural Network
#
# Next, we measure the performance of a rather deep (7-layered) multi-layer neural network on the MNIST dataset.

# %%
# Code adapted from https://github.com/activatedgeek/LeNet-5/

from collections import OrderedDict
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision.datasets.mnist import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

class MultilayerClassifier(nn.Module):
    """
    Input - 1x32x32
    Output - 10 (Output)
    """
    def __init__(self):
        super(MultilayerClassifier, self).__init__()

        self.fc = nn.Sequential(OrderedDict([
            ('fc1', nn.Linear(32 * 32, 32 * 20)),
            ('relu1', nn.ReLU()),
            ('fc2', nn.Linear(32 * 20, 32 * 16)),
            ('relu2', nn.ReLU()),
            ('fc3', nn.Linear(32 * 16, 32 * 8)),
            ('relu3', nn.ReLU()),
            ('fc4', nn.Linear(32 * 8, 32 * 4)),
            ('relu4', nn.ReLU()),
            ('fc5', nn.Linear(32 * 4, 32 * 2)),
            ('relu5', nn.ReLU()),
            ('fc6', nn.Linear(32 * 2, 16 * 2)),
            ('relu6', nn.ReLU()),
            ('fc7', nn.Linear(16 * 2, 10 * 1)),
        ]))

    def forward(self, img):
        output = img.view(-1, 32 * 32)
        output = self.fc(output)
        return output
    

data_train = MNIST('data/mnist',
                   download=True,
                   transform=transforms.Compose([
                       transforms.Resize((32, 32)),
                       transforms.ToTensor()]))
data_test = MNIST('data/mnist',
                  train=False,
                  download=True,
                  transform=transforms.Compose([
                      transforms.Resize((32, 32)),
                      transforms.ToTensor()]))
data_train_loader = DataLoader(data_train, batch_size=256, shuffle=True, num_workers=8)
data_test_loader = DataLoader(data_test, batch_size=1024, num_workers=8)

net = MultilayerClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=2e-3)

def train(epoch):
    net.train()
    loss_list, batch_list = [], []
    for i,(images, labels) in enumerate(data_train_loader):
        images, labels = Variable(images), Variable(labels)

        optimizer.zero_grad()

        output = net(images)

        loss = criterion(output, labels)

        loss_list.append(loss.data.item())
        batch_list.append(i+1)

        if i % 10 == 0:
            print('Train - Epoch %d, Batch: %d, Loss: %f' % (epoch, i, loss.data.item()))

        loss.backward()
        optimizer.step()


def test():
    net.eval()
    total_correct = 0
    avg_loss = 0.0
    for i, (images, labels) in enumerate(data_test_loader):
        images, labels = Variable(images), Variable(labels)
        output = net(images)
        avg_loss += criterion(output, labels).sum()
        pred = output.data.max(1)[1]
        total_correct += pred.eq(labels.data.view_as(pred)).sum()

    avg_loss /= len(data_test)
    print('Test Avg. Loss: %f, Accuracy: %f' % (avg_loss.data.item(), float(total_correct) / len(data_test)))


def train_and_test(epoch):
    train(epoch)
    test()


def main():
    for e in range(1, 5):  # Change 5 to 16 for better performance
        train_and_test(e)


if __name__ == '__main__':
    main()
# Out:
# Train - Epoch 1, Batch: 0, Loss: 2.303169
# Train - Epoch 3, Batch: 20, Loss: 0.086274
# Train - Epoch 3, Batch: 30, Loss: 0.082392
# Train - Epoch 3, Batch: 40, Loss: 0.050282
# Train - Epoch 3, Batch: 50, Loss: 0.135428
# Train - Epoch 3, Batch: 60, Loss: 0.105254
# Train - Epoch 3, Batch: 70, Loss: 0.032744
# Train - Epoch 3, Batch: 80, Loss: 0.108519
# Train - Epoch 3, Batch: 90, Loss: 0.161225
# Train - Epoch 3, Batch: 100, Loss: 0.069822
# Train - Epoch 3, Batch: 110, Loss: 0.095729
# Train - Epoch 3, Batch: 120, Loss: 0.073362
# Train - Epoch 3, Batch: 130, Loss: 0.156049
# Train - Epoch 3, Batch: 140, Loss: 0.069730
# Train - Epoch 3, Batch: 150, Loss: 0.081858
# Train - Epoch 3, Batch: 160, Loss: 0.126022
# Train - Epoch 3, Batch: 170, Loss: 0.122088
# Train - Epoch 3, Batch: 180, Loss: 0.097128
# Train - Epoch 3, Batch: 190, Loss: 0.109711
# Train - Epoch 3, Batch: 200, Loss: 0.072661
# Train - Epoch 3, Batch: 210, Loss: 0.083435
# Train - Epoch 3, Batch: 220, Loss: 0.075581
# Train - Epoch 3, Batch: 230, Loss: 0.027502
# Test Avg. Loss: 0.000096, Accuracy: 0.972500
# Train - Epoch 4, Batch: 0, Loss: 0.038074
# Train - Epoch 4, Batch: 10, Loss: 0.074823
# Train - Epoch 4, Batch: 20, Loss: 0.119210
# Train - Epoch 4, Batch: 30, Loss: 0.070250
# Train - Epoch 4, Batch: 40, Loss: 0.106562
# Train - Epoch 4, Batch: 50, Loss: 0.029538
# Train - Epoch 4, Batch: 60, Loss: 0.076894
# Train - Epoch 4, Batch: 70, Loss: 0.041506
# Train - Epoch 4, Batch: 80, Loss: 0.120401
# Train - Epoch 4, Batch: 90, Loss: 0.069571
# Train - Epoch 4, Batch: 100, Loss: 0.059365
# Train - Epoch 4, Batch: 110, Loss: 0.069996
# Train - Epoch 4, Batch: 120, Loss: 0.054353
# Train - Epoch 4, Batch: 130, Loss: 0.025855
# Train - Epoch 4, Batch: 140, Loss: 0.040052
# Train - Epoch 4, Batch: 150, Loss: 0.116047
# Train - Epoch 4, Batch: 160, Loss: 0.069517
# Train - Epoch 4, Batch: 170, Loss: 0.087004
# Train - Epoch 4, Batch: 180, Loss: 0.064960
# Train - Epoch 4, Batch: 190, Loss: 0.040938
# Train - Epoch 4, Batch: 200, Loss: 0.044485
# Train - Epoch 4, Batch: 210, Loss: 0.060270
# Train - Epoch 4, Batch: 220, Loss: 0.074513
# Train - Epoch 4, Batch: 230, Loss: 0.124009
# Test Avg. Loss: 0.000100, Accuracy: 0.972500

# %% [markdown]
# The accuracy we get with seven layers is also really high at 97% but it's no improvement over 2 layers.  Can we do even better?
