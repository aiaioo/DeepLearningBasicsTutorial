# %% [markdown]
# # Image Classification using a 7-Layer Neural Network
#
# Next, we measure the performance of a rather deep (7-layered) multi-layer neural network on the MNIST dataset.

# %%
# Code adapted from https://github.com/activatedgeek/LeNet-5/

from collections import OrderedDict
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision.datasets.mnist import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

class MultilayerClassifier(nn.Module):
    """
    Input - 1x32x32
    Output - 10 (Output)
    """
    def __init__(self):
        super(MultilayerClassifier, self).__init__()

        self.fc = nn.Sequential(OrderedDict([
            ('fc1', nn.Linear(32 * 32, 32 * 20)),
            ('relu1', nn.ReLU()),
            ('fc2', nn.Linear(32 * 20, 32 * 16)),
            ('relu2', nn.ReLU()),
            ('fc3', nn.Linear(32 * 16, 32 * 8)),
            ('relu3', nn.ReLU()),
            ('fc4', nn.Linear(32 * 8, 32 * 4)),
            ('relu4', nn.ReLU()),
            ('fc5', nn.Linear(32 * 4, 32 * 2)),
            ('relu5', nn.ReLU()),
            ('fc6', nn.Linear(32 * 2, 16 * 2)),
            ('relu6', nn.ReLU()),
            ('fc7', nn.Linear(16 * 2, 10 * 1)),
        ]))

    def forward(self, img):
        output = img.view(-1, 32 * 32)
        output = self.fc(output)
        return output
    

data_train = MNIST('data/mnist',
                   download=True,
                   transform=transforms.Compose([
                       transforms.Resize((32, 32)),
                       transforms.ToTensor()]))
data_test = MNIST('data/mnist',
                  train=False,
                  download=True,
                  transform=transforms.Compose([
                      transforms.Resize((32, 32)),
                      transforms.ToTensor()]))
data_train_loader = DataLoader(data_train, batch_size=256, shuffle=True, num_workers=8)
data_test_loader = DataLoader(data_test, batch_size=1024, num_workers=8)

net = MultilayerClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=2e-3)

def train(epoch):
    net.train()
    loss_list, batch_list = [], []
    for i,(images, labels) in enumerate(data_train_loader):
        images, labels = Variable(images), Variable(labels)

        optimizer.zero_grad()

        output = net(images)

        loss = criterion(output, labels)

        loss_list.append(loss.data[0])
        batch_list.append(i+1)

        if i % 10 == 0:
            print('Train - Epoch %d, Batch: %d, Loss: %f' % (epoch, i, loss.data[0]))

        loss.backward()
        optimizer.step()


def test():
    net.eval()
    total_correct = 0
    avg_loss = 0.0
    for i, (images, labels) in enumerate(data_test_loader):
        images, labels = Variable(images), Variable(labels)
        output = net(images)
        avg_loss += criterion(output, labels).sum()
        pred = output.data.max(1)[1]
        total_correct += pred.eq(labels.data.view_as(pred)).sum()

    avg_loss /= len(data_test)
    print('Test Avg. Loss: %f, Accuracy: %f' % (avg_loss.data[0], float(total_correct) / len(data_test)))


def train_and_test(epoch):
    train(epoch)
    test()


def main():
    for e in range(1, 5):  # Change 5 to 16 for better performance
        train_and_test(e)


if __name__ == '__main__':
    main()
# Out:
# Train - Epoch 1, Batch: 0, Loss: 2.310225
# Train - Epoch 3, Batch: 10, Loss: 0.106085
# Train - Epoch 3, Batch: 20, Loss: 0.067320
# Train - Epoch 3, Batch: 30, Loss: 0.088858
# Train - Epoch 3, Batch: 40, Loss: 0.112248
# Train - Epoch 3, Batch: 50, Loss: 0.137599
# Train - Epoch 3, Batch: 60, Loss: 0.109973
# Train - Epoch 3, Batch: 70, Loss: 0.138630
# Train - Epoch 3, Batch: 80, Loss: 0.070629
# Train - Epoch 3, Batch: 90, Loss: 0.031438
# Train - Epoch 3, Batch: 100, Loss: 0.061572
# Train - Epoch 3, Batch: 110, Loss: 0.087362
# Train - Epoch 3, Batch: 120, Loss: 0.125089
# Train - Epoch 3, Batch: 130, Loss: 0.101104
# Train - Epoch 3, Batch: 140, Loss: 0.104983
# Train - Epoch 3, Batch: 150, Loss: 0.045053
# Train - Epoch 3, Batch: 160, Loss: 0.117199
# Train - Epoch 3, Batch: 170, Loss: 0.055308
# Train - Epoch 3, Batch: 180, Loss: 0.079768
# Train - Epoch 3, Batch: 190, Loss: 0.122202
# Train - Epoch 3, Batch: 200, Loss: 0.102217
# Train - Epoch 3, Batch: 210, Loss: 0.147399
# Train - Epoch 3, Batch: 220, Loss: 0.147078
# Train - Epoch 3, Batch: 230, Loss: 0.022247
# Test Avg. Loss: 0.000100, Accuracy: 0.971400
# Train - Epoch 4, Batch: 0, Loss: 0.059718
# Train - Epoch 4, Batch: 10, Loss: 0.015339
# Train - Epoch 4, Batch: 20, Loss: 0.042337
# Train - Epoch 4, Batch: 30, Loss: 0.079504
# Train - Epoch 4, Batch: 40, Loss: 0.047410
# Train - Epoch 4, Batch: 50, Loss: 0.105557
# Train - Epoch 4, Batch: 60, Loss: 0.095350
# Train - Epoch 4, Batch: 70, Loss: 0.068290
# Train - Epoch 4, Batch: 80, Loss: 0.056009
# Train - Epoch 4, Batch: 90, Loss: 0.031582
# Train - Epoch 4, Batch: 100, Loss: 0.055053
# Train - Epoch 4, Batch: 110, Loss: 0.031098
# Train - Epoch 4, Batch: 120, Loss: 0.092202
# Train - Epoch 4, Batch: 130, Loss: 0.069467
# Train - Epoch 4, Batch: 140, Loss: 0.033751
# Train - Epoch 4, Batch: 150, Loss: 0.122426
# Train - Epoch 4, Batch: 160, Loss: 0.108892
# Train - Epoch 4, Batch: 170, Loss: 0.033920
# Train - Epoch 4, Batch: 180, Loss: 0.031740
# Train - Epoch 4, Batch: 190, Loss: 0.078655
# Train - Epoch 4, Batch: 200, Loss: 0.059402
# Train - Epoch 4, Batch: 210, Loss: 0.054419
# Train - Epoch 4, Batch: 220, Loss: 0.090425
# Train - Epoch 4, Batch: 230, Loss: 0.101165
# Test Avg. Loss: 0.000098, Accuracy: 0.972600

# %% [markdown]
# The accuracy we get with seven layers is also really high at 97%.  Can we do even better?
